# %%
import pandas as pd

# %%
csv_file=pd.read_csv('D:\\100 Sales Records.csv')
csv_file
# Out:
#                   Region                Country        Item Type  \
# 0  Australia and Oceania                 Tuvalu        Baby Food
# 1                     BD             Bangladesh        Cosmetics
# 2                 Europe                 Russia  Office Supplies
# 3     Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4     Sub-Saharan Africa                 Rwanda  Office Supplies
# 5  Australia and Oceania        Solomon Islands        Baby Food
# 6     Sub-Saharan Africa                 Angola        Household
# 7     Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                    NaN                    NaN              NaN
#
#   Sales Channel Order Priority Order Date     Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933.0  6/27/2010      9925.0
# 1        online              F  8/22/2012  963881480.0  9/15/2012      2804.0
# 2       Offline              L   5/2/2014  341417157.0   5/8/2014      1779.0
# ...

# %%
csv_file=pd.read_csv('D:\\100 Sales Records.csv',index_col=[1] ,nrows=5,usecols=['Region','Country'],names=None)
csv_file
# Out:
#                                       Region
# Country
# Tuvalu                 Australia and Oceania
# Bangladesh                                BD
# Russia                                Europe
# Sao Tome and Principe     Sub-Saharan Africa
# Rwanda                    Sub-Saharan Africa

# %%
csv_file=pd.read_csv('D:\\100 Sales Records.csv',skiprows=[1,2,3], skipfooter=5,engine='python')
csv_file
# Out:
#                Region                Country Item Type Sales Channel  \
# 0  Sub-Saharan Africa  Sao Tome and Principe    Fruits        Online
#
#   Order Priority Order Date   Order ID Ship Date  Units Sold  Unit Price  \
# 0              C  6/20/2014  514321792  7/5/2014        8102        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0       6.92       75591.66    56065.84      19525.82

# %%
csv_file=pd.read_csv('D:\\100 Sales Records.csv')
csv_file.head()
csv_file.tail()
# Out:
#                   Region          Country        Item Type Sales Channel  \
# 4     Sub-Saharan Africa           Rwanda  Office Supplies       Offline
# 5  Australia and Oceania  Solomon Islands        Baby Food        Online
# 6     Sub-Saharan Africa           Angola        Household       Offline
# 7     Sub-Saharan Africa     Burkina Faso       Vegetables        Online
# 8                    NaN              NaN              NaN           NaN
#
#   Order Priority Order Date     Order ID  Ship Date  Units Sold  Unit Price  \
# 4              L   2/1/2013  115456712.0   2/6/2013      5062.0      651.21
# 5              C   2/4/2015  547995746.0  2/21/2015      2974.0      255.28
# 6              M  4/23/2011  135425221.0  4/27/2011      4187.0      668.27
# 7              H  7/17/2012  871543967.0  7/27/2012      8082.0      154.06
# 8            NaN        NaN          NaN        NaN         NaN         NaN
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
csv_file=pd.read_csv('D:\\100 Sales Records.csv',na_values=['Tuvalu','Fruits'])
csv_file.head()
# Out:
#                   Region                Country        Item Type  \
# 0  Australia and Oceania                    NaN        Baby Food
# 1                     BD             Bangladesh        Cosmetics
# 2                 Europe                 Russia  Office Supplies
# 3     Sub-Saharan Africa  Sao Tome and Principe              NaN
# 4     Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010       9925
# 1        online              F  8/22/2012  963881480  9/15/2012       2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014       1779
# 3        Online              C  6/20/2014  514321792   7/5/2014       8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013       5062
#
#   Unit Price Unit Cost Total Revenue  Total Cost Total Profit
# ...

# %%
csv_file=pd.read_csv('D:\\100 Sales Records.csv')
csv_file.head()
# Out:
#                   Region                Country        Item Type  \
# 0  Australia and Oceania                 Tuvalu        Baby Food
# 1                     BD             Bangladesh        Cosmetics
# 2                 Europe                 Russia  Office Supplies
# 3     Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4     Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date     Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933.0  6/27/2010      9925.0
# 1        online              F  8/22/2012  963881480.0  9/15/2012      2804.0
# 2       Offline              L   5/2/2014  341417157.0   5/8/2014      1779.0
# 3        Online              C  6/20/2014  514321792.0   7/5/2014      8102.0
# 4       Offline              L   2/1/2013  115456712.0   2/6/2013      5062.0
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %% [markdown]
# ## use 'nrows' for taking a bunch of specific rows you need ,nrows=5 that means I am taking first five rows from the all
#
# ## use 'usecols' for talking only specific columns you need like nrows
#
# ## 'index_cols' for making a column as index
#
# ## 'prefix' for giving one name to all the columns heading
#
# ## 'skiprows' for skiping rows itself
#
# ## use 'head' and 'tail' veriable function to make out as first five and the last
#
# ## use 'na_values' for making a specific value to Nane ,na_values='rifat',rifa will be none
#
# ## use dict in 'dtype' for changing ones data type
#
# ## 'header' for making a row as head
#
# ## 'keep_default_na' for removing fake items to nane
#
# ## 'names' for changing header name
